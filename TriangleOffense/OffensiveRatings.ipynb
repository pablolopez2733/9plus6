# %%
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

# %%
#Leemos datos
df=pd.read_csv("LALSeasons.csv")
df.head()
# Out:
#   Temporada    W/L   ORtg   DRtg  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0   1997-98  0.744  111.9  103.7         NaN         NaN         NaN
# 1   1998-99  0.620  107.6  104.3         NaN         NaN         NaN
# 2   1999-00  0.817  107.3   98.2         NaN         NaN         NaN
# 3   2000-01  0.683  108.4  104.8         NaN         NaN         NaN
# 4   2001-02  0.707  109.4  101.7         NaN         NaN         NaN
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 12  Unnamed: 13  \
# 0         NaN         NaN         NaN  ...          NaN          NaN
# 1         NaN         NaN         NaN  ...          NaN          NaN
# 2         NaN         NaN         NaN  ...          NaN          NaN
# 3         NaN         NaN         NaN  ...          NaN          NaN
# 4         NaN         NaN         NaN  ...          NaN          NaN
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 19  Unnamed: 20  Unnamed: 21
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN
#
# [5 rows x 22 columns]

# %%
#Limpiamos columnas molestas
cols = []
for i in range (4,22):
    cols.append(i)

df.drop(df.columns[cols],axis=1,inplace=True)
df.head()
# Out:
#   Temporada    W/L   ORtg   DRtg
# 0   1997-98  0.744  111.9  103.7
# 1   1998-99  0.620  107.6  104.3
# 2   1999-00  0.817  107.3   98.2
# 3   2000-01  0.683  108.4  104.8
# 4   2001-02  0.707  109.4  101.7

# %%
#df_Ortg=df[['Temporada', 'ORtg']].copy()
#g = sns.relplot(x="Temporada", y="ORtg", data=df)
xlabels=df["Temporada"]
ax = sns.lineplot(x="Temporada", y="ORtg", data=df,marker='o',color='blueviolet')
ax.set_xticklabels(xlabels,rotation=90)
ax.set_title('ORtg por temporada de los Lakers')
sns.set_style("whitegrid")
